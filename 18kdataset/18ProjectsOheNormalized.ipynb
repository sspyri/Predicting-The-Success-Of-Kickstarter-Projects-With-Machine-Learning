# %%
import pandas as pd
import numpy as np
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from sklearn.model_selection import cross_val_score

# %matplotlib inline



training_accuracy = []
test_accuracy = []

df = pd.read_csv(r'C:\Users\dungeon\Downloads\ml_data\18kprojects\MissingDataSolutions\mean\18kOHEandNormalization_removecategory.csv')

X = df.drop(columns=['State','Pledged','Backers'])

y = df['State'].values

# Split dataset into train and test data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 42,stratify=y)

# Range of n_neighbors tested
neighbors_settings = range(1,50)

# Create KNN classifier for range of n_neighbors
for num_neighbors in neighbors_settings: 
     knn = KNeighborsClassifier(n_neighbors = num_neighbors)

# Fit the classifier to the data

     knn.fit(X_train, y_train)
     
     training_accuracy.append(knn.score(X_train, y_train))

     test_accuracy.append(knn.score(X_test, y_test))
     

# Check accuracy of our model on the test data
     print(num_neighbors, knn.score(X_test, y_test))
    
# Data visualization - Evaluatin the accuracy of both the training and the testing sets against
# n_neighbors
plt.plot(neighbors_settings, training_accuracy, label='Accuracy of the Training Test')
plt.plot(neighbors_settings, test_accuracy, label='Accuracy of the Test Set')
plt.ylabel('Accuracy')
plt.xlabel('Number of Neighbors')
plt.legend()
# Out:
# 1 0.6362460742656567
# 2 0.6294106779974137
# 3 0.6639571402179937
# 4 0.647699981525956
# 5 0.6696840938481433
# 6 0.6652503232957695
# 7 0.6741178644005172
# 8 0.6726399408830593
# 9 0.67762793275448
# 10 0.6730094217624238
# 11 0.6818769628671716
# 12 0.6759652687973398
# 13 0.6820617033068539
# 14 0.6835396268243118
# 15 0.6872344356179567
# 16 0.6876039164973212
# 17 0.687419176057639
# 18 0.6844633290227231
# 19 0.6905597635322372
# 20 0.6842785885830408
# 21 0.6885276186957325
# 22 0.6839091077036763
# 23 0.6855717716608165
# 24 0.6811380011084427
# 25 0.6828006650655829
# 26 0.6781821540735267
# 27 0.6842785885830408
# 28 0.6805837797893959
# 29 0.6824311841862184
# 30 0.6805837797893959
# 31 0.6846480694624053
# 32 0.6822464437465361
# 33 0.6855717716608165
# 34 0.6807685202290782
# 35 0.6840938481433586
# 36 0.6828006650655829
# 37 0.6842785885830408
# 38 0.6824311841862184
# 39 0.6829854055052651
# 40 0.6828006650655829
# 41 0.6857565121004988
# 42 0.6833548863846296
# 43 0.6844633290227231
# 44 0.685202290781452
# 45 0.6839091077036763
# 46 0.685202290781452
# 47 0.6850175503417698
# 48 0.6840938481433586
# 49 0.6839091077036763
